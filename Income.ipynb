# %%
# %matplotlib inline
from matplotlib.pylab import plt

import pandas as pd
import numpy as np

# %% [markdown]
# # Let's look at some data with seasonality + trend

# %%
path = r"C:\Users\pınar hoca\Desktop\time_profit1.txt"

# %%
import pandas as pd

path = 'https://raw.githubusercontent.com/pinarsen79/time_seri/main/Income.csv'
df = pd.read_csv(path, header=0)

print(df.shape)
print(df.head())
# Out:
# (399, 2)
#   purchase_date  Income
# 0     6.03.2024  1.7536
# 1     6.04.2024  1.7536
# 2     6.05.2024  1.7552
# 3     6.06.2024  1.7536
# 4     6.07.2024  1.4616

# %%
df = pd.read_csv(path, header=0)

print(df.shape)
print(df.head())
# Out:
# (399, 2)
#   purchase_date  Income
# 0     6.03.2024  1.7536
# 1     6.04.2024  1.7536
# 2     6.05.2024  1.7552
# 3     6.06.2024  1.7536
# 4     6.07.2024  1.4616

# %%
from matplotlib import pyplot

df.plot()
pyplot.show()

# %%
log_air_passengers = np.log(air_passengers.Passengers)
log_air_passengers_diff = log_air_passengers - log_air_passengers.shift()
plt.plot(log_air_passengers_diff)

# %%
df.dtypes
# Out:
# purchase_date     object
# Income           float64
# dtype: object

# %%
df.columns = ['ds', 'y']
df['ds']= pd.to_datetime(df['ds'])

# %%
future = list()

for i in range(1, 13):
    date = '2023-%02d' % i
    future.append([date])
    
future = pd.DataFrame(future)
future.columns = ['ds']
future['ds']= pd.to_datetime(future['ds'])
forecast = model.predict(future)

# %%
model.plot(forecast)
pyplot.show()
# Out:
# C:\Users\pınar hoca\AppData\Roaming\Python\Python311\site-packages\prophet\plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# C:\Users\pınar hoca\AppData\Roaming\Python\Python311\site-packages\prophet\plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
future = list()

for i in range(1, 13):
    date = '2024-%02d' % i
    future.append([date])
    
future = pd.DataFrame(future)
future.columns = ['ds']
future['ds']= pd.to_datetime(future['ds'])

forecast = model.predict(future)
print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].head())

model.plot(forecast)
pyplot.show()
# Out:
#           ds       yhat  yhat_lower  yhat_upper
# 0 2024-01-01  52.862768   23.916836   80.700025
# 1 2024-02-01  54.267639   24.880551   82.933879
# 2 2024-03-01  55.581873   27.309177   81.760568
# 3 2024-04-01  56.986744   28.136620   86.349910
# 4 2024-05-01  58.346297   28.553531   86.389510
# C:\Users\pınar hoca\AppData\Roaming\Python\Python311\site-packages\prophet\plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# ...

# %%
import pandas as pd
from prophet import Prophet
from sklearn.metrics import mean_absolute_error
from matplotlib import pyplot

path = 'https://raw.githubusercontent.com/pinarsen79/time_seri/main/Income.csv'
df = pd.read_csv(path, header=0)

df.columns = ['ds', 'y']
df['ds']= pd.to_datetime(df['ds'])

# %%
train = df.drop(df.index[-12:])
print(train.tail())
# Out:
#             ds       y
# 382 2025-06-20  1.7512
# 383 2025-06-21  1.7512
# 384 2025-06-22  0.7912
# 385 2025-06-23  1.7512
# 386 2025-06-24  1.7512

# %%
y_true = df['y'][-12:].values
y_pred = forecast['yhat'].values

# %%
mae = mean_absolute_error(y_true, y_pred)
print('MAE: %.3f' % mae)
# Out:
# MAE: 58.502

# %%
pyplot.plot(y_true, label='Actual')
pyplot.plot(y_pred, label='Predicted')
pyplot.legend()
pyplot.show()
